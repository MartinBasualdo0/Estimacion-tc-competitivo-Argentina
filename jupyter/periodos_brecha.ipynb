# %%
from config_jupyter import set_wd
set_wd()
import src.periodos_brecha as pbre
pbre.main()

# %%
pbre.plot_brecha(fecha_ini='2019-6-15'
            )

# %%
pbre.plot_brecha(fecha_ini='2003-01-01',
        fecha_fin='2007-03-01'
        )

pbre.plot_brecha(fecha_ini='2006-9-01',
            fecha_fin='2012-3-01'
            )


pbre.plot_brecha(fecha_ini='2011-09-01',
            fecha_fin='2016-03-01',
            )

pbre.plot_brecha(fecha_ini='2015-10-15',
            fecha_fin='2020-1-01',
            )
